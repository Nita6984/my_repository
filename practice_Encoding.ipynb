# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
data = {'Education':['SSC','PG','Grad','HSC','PG','PhD','HSC','PG','SSC','Grad'],
        'City_Names':['Pune','Mumbai','Chennai','Pune','Delhi','Mumbai','Pune','Pune','Chennai','Delhi'],
       'Genre':['Crime','Action','Comedy','Thriller','Action','Drama','Comedy','Thriller','Crime','Drama'],
       'Duration':[142,156,180,165,115,200,195,160,150,142]}

df = pd.DataFrame(data)
df
# Out:
#   Education City_Names     Genre  Duration
# 0       SSC       Pune     Crime       142
# 1        PG     Mumbai    Action       156
# 2      Grad    Chennai    Comedy       180
# 3       HSC       Pune  Thriller       165
# 4        PG      Delhi    Action       115
# 5       PhD     Mumbai     Drama       200
# 6       HSC       Pune    Comedy       195
# 7        PG       Pune  Thriller       160
# 8       SSC    Chennai     Crime       150
# 9      Grad      Delhi     Drama       142

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Education   10 non-null     object
#  1   City_Names  10 non-null     object
#  2   Genre       10 non-null     object
#  3   Duration    10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df.replace({'SSC':0, 'HSC':1, 'Grad':2 , 'PG': 3, 'PhD':4}, inplace=True)

# %%
df
# Out:
#    Education City_Names     Genre  Duration
# 0          0       Pune     Crime       142
# 1          3     Mumbai    Action       156
# 2          2    Chennai    Comedy       180
# 3          1       Pune  Thriller       165
# 4          3      Delhi    Action       115
# 5          4     Mumbai     Drama       200
# 6          1       Pune    Comedy       195
# 7          3       Pune  Thriller       160
# 8          0    Chennai     Crime       150
# 9          2      Delhi     Drama       142

# %% [markdown]
# ### pd.get_dummies()

# %%
df['City_Names'].unique()
# Out:
# array(['Pune', 'Mumbai', 'Chennai', 'Delhi'], dtype=object)

# %%
pd.get_dummies(df['City_Names'])
# Out:
#    Chennai  Delhi  Mumbai   Pune
# 0    False  False   False   True
# 1    False  False    True  False
# 2     True  False   False  False
# 3    False  False   False   True
# 4    False   True   False  False
# 5    False  False    True  False
# 6    False  False   False   True
# 7    False  False   False   True
# 8     True  False   False  False
# 9    False   True   False  False

# %%
pd.get_dummies(df['Genre'])
# Out:
#    Action  Comedy  Crime  Drama  Thriller
# 0   False   False   True  False     False
# 1    True   False  False  False     False
# 2   False    True  False  False     False
# 3   False   False  False  False      True
# 4    True   False  False  False     False
# 5   False   False  False   True     False
# 6   False    True  False  False     False
# 7   False   False  False  False      True
# 8   False   False   True  False     False
# 9   False   False  False   True     False

# %%
pd.get_dummies(df, columns=['City_Names','Genre'])
# Out:
#    Education  Duration  City_Names_Chennai  City_Names_Delhi  \
# 0          0       142               False             False
# 1          3       156               False             False
# 2          2       180                True             False
# 3          1       165               False             False
# 4          3       115               False              True
# 5          4       200               False             False
# 6          1       195               False             False
# 7          3       160               False             False
# 8          0       150                True             False
# 9          2       142               False              True
#
#    City_Names_Mumbai  City_Names_Pune  Genre_Action  Genre_Comedy  \
# 0              False             True         False         False
# 1               True            False          True         False
# 2              False            False         False          True
# ...

# %%
pd.get_dummies(df['Genre'],prefix='Genre',)

# %%
pd.get_dummies(df['City_Names'],prefix='City', drop_first=True)
# Out:
#    City_Delhi  City_Mumbai  City_Pune
# 0       False        False       True
# 1       False         True      False
# 2       False        False      False
# 3       False        False       True
# 4        True        False      False
# 5       False         True      False
# 6       False        False       True
# 7       False        False       True
# 8       False        False      False
# 9        True        False      False

# %%
pd.get_dummies(df,drop_first=True)
# Out:
#    Education  Duration  City_Names_Delhi  City_Names_Mumbai  City_Names_Pune  \
# 0          0       142             False              False             True
# 1          3       156             False               True            False
# 2          2       180             False              False            False
# 3          1       165             False              False             True
# 4          3       115              True              False            False
# 5          4       200             False               True            False
# 6          1       195             False              False             True
# 7          3       160             False              False             True
# 8          0       150             False              False            False
# 9          2       142              True              False            False
#
#    Genre_Comedy  Genre_Crime  Genre_Drama  Genre_Thriller
# 0         False         True        False           False
# ...

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data = {'Education':['SSC','PG','SSC','PG','PG','PhD','HSC','PG','SSC','Grad'],
        'City_Names':['Pune','Mumbai','Pune','Mumbai','Delhi','Mumbai','Pune','Pune','Chennai','Delhi'],
       'Genre':['Crime','Action','Crime','Action','Action','Drama','Comedy','Thriller','Crime','Drama'],
       'Duration':[142,156,142,115,200,142,156,160,156,142]}

# Reading Data
df = pd.DataFrame(data)
df
# Out:
#   Education City_Names     Genre  Duration
# 0       SSC       Pune     Crime       142
# 1        PG     Mumbai    Action       156
# 2       SSC       Pune     Crime       142
# 3        PG     Mumbai    Action       115
# 4        PG      Delhi    Action       200
# 5       PhD     Mumbai     Drama       142
# 6       HSC       Pune    Comedy       156
# 7        PG       Pune  Thriller       160
# 8       SSC    Chennai     Crime       156
# 9      Grad      Delhi     Drama       142

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(keep='first')
# Out:
#   Education City_Names     Genre  Duration
# 0       SSC       Pune     Crime       142
# 1        PG     Mumbai    Action       156
# 3        PG     Mumbai    Action       115
# 4        PG      Delhi    Action       200
# 5       PhD     Mumbai     Drama       142
# 6       HSC       Pune    Comedy       156
# 7        PG       Pune  Thriller       160
# 8       SSC    Chennai     Crime       156
# 9      Grad      Delhi     Drama       142

# %%
df.drop_duplicates(keep='last')
# Out:
#   Education City_Names     Genre  Duration
# 1        PG     Mumbai    Action       156
# 2       SSC       Pune     Crime       142
# 3        PG     Mumbai    Action       115
# 4        PG      Delhi    Action       200
# 5       PhD     Mumbai     Drama       142
# 6       HSC       Pune    Comedy       156
# 7        PG       Pune  Thriller       160
# 8       SSC    Chennai     Crime       156
# 9      Grad      Delhi     Drama       142

# %%
df = pd.read_csv('salary.csv')
df
# Out:
#      YearsExperience  Age  Industry  Country  Salary
# 0                1.1   23   Fashion    china   39343
# 1                1.3   40   Banking    india   46205
# 2                1.5   22  Accounts  nigeria   37731
# 3                2.0   26      Tech    china   43525
# 4                2.2   28       NaN  britain   39891
# ..               ...  ...       ...      ...     ...
# 115              9.0   48  medicine    india  105582
# 116              9.5   46   Banking  britain  116969
# 117              9.6   31  medicine  britain  112635
# 118             10.3   53      Tech  britain  122391
# 119             10.5   48  Accounts    india  121872
#
# [120 rows x 5 columns]

# %%
df['Country'].unique()
# Out:
# array(['china', 'india', 'nigeria', 'britain', nan], dtype=object)

# %%
df['Country'].nunique()
# Out:
# 4

# %%
df['Country'].value_counts()
# Out:
# Country
# india      48
# china      32
# nigeria    16
# britain    16
# Name: count, dtype: int64

# %%
sal_df= df.copy()
sal_df
# Out:
#      YearsExperience  Age  Industry  Country  Salary
# 0                1.1   23   Fashion    china   39343
# 1                1.3   40   Banking    india   46205
# 2                1.5   22  Accounts  nigeria   37731
# 3                2.0   26      Tech    china   43525
# 4                2.2   28       NaN  britain   39891
# ..               ...  ...       ...      ...     ...
# 115              9.0   48  medicine    india  105582
# 116              9.5   46   Banking  britain  116969
# 117              9.6   31  medicine  britain  112635
# 118             10.3   53      Tech  britain  122391
# 119             10.5   48  Accounts    india  121872
#
# [120 rows x 5 columns]

# %%
new_df= pd.get_dummies(df['Country'], prefix= 'Country')
new_df
# Out:
#      Country_britain  Country_china  Country_india  Country_nigeria
# 0              False           True          False            False
# 1              False          False           True            False
# 2              False          False          False             True
# 3              False           True          False            False
# 4               True          False          False            False
# ..               ...            ...            ...              ...
# 115            False          False           True            False
# 116             True          False          False            False
# 117             True          False          False            False
# 118             True          False          False            False
# 119            False          False           True            False
#
# [120 rows x 4 columns]

# %%
new_df= pd.get_dummies(df['Country'], prefix= 'Country', drop_first=True)
new_df.head()
# Out:
#    Country_china  Country_india  Country_nigeria
# 0           True          False            False
# 1          False           True            False
# 2          False          False             True
# 3           True          False            False
# 4          False          False            False

# %%
new_df= pd.get_dummies(df['Country'], prefix= 'Country', drop_first=True)
new_df
# Out:
#      Country_china  Country_india  Country_nigeria
# 0             True          False            False
# 1            False           True            False
# 2            False          False             True
# 3             True          False            False
# 4            False          False            False
# ..             ...            ...              ...
# 115          False           True            False
# 116          False          False            False
# 117          False          False            False
# 118          False          False            False
# 119          False           True            False
#
# [120 rows x 3 columns]

# %%
df=pd.concat([df, new_df], axis=1)
df
# Out:
#      YearsExperience  Age  Industry  Country  Salary  Country_china  \
# 0                1.1   23   Fashion    china   39343           True
# 1                1.3   40   Banking    india   46205          False
# 2                1.5   22  Accounts  nigeria   37731          False
# 3                2.0   26      Tech    china   43525           True
# 4                2.2   28       NaN  britain   39891          False
# ..               ...  ...       ...      ...     ...            ...
# 115              9.0   48  medicine    india  105582          False
# 116              9.5   46   Banking  britain  116969          False
# 117              9.6   31  medicine  britain  112635          False
# 118             10.3   53      Tech  britain  122391          False
# 119             10.5   48  Accounts    india  121872          False
#
#      Country_india  Country_nigeria
# 0            False            False
# 1             True            False
# 2            False             True
# ...

# %%
df.drop('Country', axis=1, inplace=True)

# %%
df
# Out:
#      YearsExperience  Age  Industry  Salary  Country_china  Country_india  \
# 0                1.1   23   Fashion   39343           True          False
# 1                1.3   40   Banking   46205          False           True
# 2                1.5   22  Accounts   37731          False          False
# 3                2.0   26      Tech   43525           True          False
# 4                2.2   28       NaN   39891          False          False
# ..               ...  ...       ...     ...            ...            ...
# 115              9.0   48  medicine  105582          False           True
# 116              9.5   46   Banking  116969          False          False
# 117              9.6   31  medicine  112635          False          False
# 118             10.3   53      Tech  122391          False          False
# 119             10.5   48  Accounts  121872          False           True
#
#      Country_nigeria
# 0              False
# 1              False
# ...

# %%
df = df.join(new_df)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = df.join(new_df)
#       2 df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:9729, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9566 def join(
#    9567     self,
#    9568     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9574     validate: str | None = None,
#    9575 ) -> DataFrame:
#    9576     """
#    9577     Join columns of another DataFrame.
#    9578
#    (...)
#    9727     5  K1  A5   B1
#    9728     """
# -> 9729     return self._join_compat(
#    9730         other,
#    9731         on=on,
#    9732         how=how,
#    9733         lsuffix=lsuffix,
#    9734         rsuffix=rsuffix,
#    9735         sort=sort,
#    9736         validate=validate,
#    9737     )
#
# ...

# %%
df2=df.iloc[:, :3]
df2
# Out:
#      YearsExperience  Age  Industry
# 0                1.1   23   Fashion
# 1                1.3   40   Banking
# 2                1.5   22  Accounts
# 3                2.0   26      Tech
# 4                2.2   28       NaN
# ..               ...  ...       ...
# 115              9.0   48  medicine
# 116              9.5   46   Banking
# 117              9.6   31  medicine
# 118             10.3   53      Tech
# 119             10.5   48  Accounts
#
# [120 rows x 3 columns]

# %%
new_df
# Out:
#      Country_china  Country_india  Country_nigeria
# 0             True          False            False
# 1            False           True            False
# 2            False          False             True
# 3             True          False            False
# 4            False          False            False
# ..             ...            ...              ...
# 115          False           True            False
# 116          False          False            False
# 117          False          False            False
# 118          False          False            False
# 119          False           True            False
#
# [120 rows x 3 columns]

# %%
sal_df
# Out:
#      YearsExperience  Age  Industry  Country  Salary
# 0                1.1   23   Fashion    china   39343
# 1                1.3   40   Banking    india   46205
# 2                1.5   22  Accounts  nigeria   37731
# 3                2.0   26      Tech    china   43525
# 4                2.2   28       NaN  britain   39891
# ..               ...  ...       ...      ...     ...
# 115              9.0   48  medicine    india  105582
# 116              9.5   46   Banking  britain  116969
# 117              9.6   31  medicine  britain  112635
# 118             10.3   53      Tech  britain  122391
# 119             10.5   48  Accounts    india  121872
#
# [120 rows x 5 columns]

# %%
df = df2.join(new_df)
df
# Out:
#      YearsExperience  Age  Industry  Country_china  Country_india  \
# 0                1.1   23   Fashion           True          False
# 1                1.3   40   Banking          False           True
# 2                1.5   22  Accounts          False          False
# 3                2.0   26      Tech           True          False
# 4                2.2   28       NaN          False          False
# ..               ...  ...       ...            ...            ...
# 115              9.0   48  medicine          False           True
# 116              9.5   46   Banking          False          False
# 117              9.6   31  medicine          False          False
# 118             10.3   53      Tech          False          False
# 119             10.5   48  Accounts          False           True
#
#      Country_nigeria
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
# ..               ...
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 115     True
# 116     True
# 117     True
# 118     True
# 119     True
# Length: 120, dtype: bool

# %%
df.duplicated().any()
# Out:
# True

# %%
df.duplicated().all()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 90

# %%
df.drop_duplicates().shape
# Out:
# (30, 6)

# %%
df
# Out:
#      YearsExperience  Age  Industry  Country_china  Country_india  \
# 0                1.1   23   Fashion           True          False
# 1                1.3   40   Banking          False           True
# 2                1.5   22  Accounts          False          False
# 3                2.0   26      Tech           True          False
# 4                2.2   28       NaN          False          False
# ..               ...  ...       ...            ...            ...
# 115              9.0   48  medicine          False           True
# 116              9.5   46   Banking          False          False
# 117              9.6   31  medicine          False          False
# 118             10.3   53      Tech          False          False
# 119             10.5   48  Accounts          False           True
#
#      Country_nigeria
# 0              False
# 1              False
# 2               True
# 3              False
# 4              False
# ..               ...
# ...

# %%
df.drop_duplicates(keep='last')
# Out:
#      YearsExperience  Age  Industry  Country_china  Country_india  \
# 90               1.1   23   Fashion           True          False
# 91               1.3   40   Banking          False           True
# 92               1.5   22  Accounts          False          False
# 93               2.0   26      Tech           True          False
# 94               2.2   28       NaN          False          False
# 95               2.9   31       NaN          False          False
# 96               3.0   47   Banking          False           True
# 97               3.2   36  medicine          False          False
# 98               3.2   53   Fashion          False           True
# 99               3.7   43       NaN          False           True
# 100              3.9   37       NaN          False          False
# 101              4.0   54   fashion           True          False
# 102              4.0   26       NaN          False           True
# ...

# %%
salary_df=pd.read_csv('salary.csv')
salary_df
# Out:
#      YearsExperience  Age  Industry  Country  Salary
# 0                1.1   23   Fashion    china   39343
# 1                1.3   40   Banking    india   46205
# 2                1.5   22  Accounts  nigeria   37731
# 3                2.0   26      Tech    china   43525
# 4                2.2   28       NaN  britain   39891
# ..               ...  ...       ...      ...     ...
# 115              9.0   48  medicine    india  105582
# 116              9.5   46   Banking  britain  116969
# 117              9.6   31  medicine  britain  112635
# 118             10.3   53      Tech  britain  122391
# 119             10.5   48  Accounts    india  121872
#
# [120 rows x 5 columns]

# %%
print(salary_df['Age'].min())
print(salary_df['Age'].max())
# Out:
# 22
# 56

# %%
bins=[20,25,30,35,40,45,50,60]
labels=['20_25yrs','25_30yrs','30_35yrs','35_40yrs','40_45yrs','45_50yrs','50_60yrs']

# %%
salary_df['Age_groups']= pd.cut(df['Age'], bins=bins, labels= labels, include_lowest=True)
salary_df
# Out:
#      YearsExperience  Age  Industry  Country  Salary Age_groups
# 0                1.1   23   Fashion    china   39343   20_25yrs
# 1                1.3   40   Banking    india   46205   35_40yrs
# 2                1.5   22  Accounts  nigeria   37731   20_25yrs
# 3                2.0   26      Tech    china   43525   25_30yrs
# 4                2.2   28       NaN  britain   39891   25_30yrs
# ..               ...  ...       ...      ...     ...        ...
# 115              9.0   48  medicine    india  105582   45_50yrs
# 116              9.5   46   Banking  britain  116969   45_50yrs
# 117              9.6   31  medicine  britain  112635   30_35yrs
# 118             10.3   53      Tech  britain  122391   50_60yrs
# 119             10.5   48  Accounts    india  121872   45_50yrs
#
# [120 rows x 6 columns]

# %%
salary_df['Age_groups2']= pd.qcut(df['Age'],8)
salary_df
# Out:
#      YearsExperience  Age  Industry  Country  Salary Age_groups  \
# 0                1.1   23   Fashion    china   39343   20_25yrs
# 1                1.3   40   Banking    india   46205   35_40yrs
# 2                1.5   22  Accounts  nigeria   37731   20_25yrs
# 3                2.0   26      Tech    china   43525   25_30yrs
# 4                2.2   28       NaN  britain   39891   25_30yrs
# ..               ...  ...       ...      ...     ...        ...
# 115              9.0   48  medicine    india  105582   45_50yrs
# 116              9.5   46   Banking  britain  116969   45_50yrs
# 117              9.6   31  medicine  britain  112635   30_35yrs
# 118             10.3   53      Tech  britain  122391   50_60yrs
# 119             10.5   48  Accounts    india  121872   45_50yrs
#
#         Age_groups2
# 0    (21.999, 26.0]
# 1      (36.0, 44.5]
# 2    (21.999, 26.0]
# 3    (21.999, 26.0]
# 4      (26.0, 31.0]
# ..              ...
# 115    (44.5, 48.0]
# 116    (44.5, 48.0]
# ...
